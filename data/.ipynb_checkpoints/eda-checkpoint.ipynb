# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
path_to_clean_df='..\..\data\clean.csv'
df=pd.read_csv(path_to_clean_df)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\matth\AppData\Local\Temp\ipykernel_6384\630805374.py:1: SyntaxWarning: invalid escape sequence '\.'
#   path_to_clean_df='..\..\data\clean.csv'

# %% [markdown]
# ### Number of songs per decade: ###

# %%
yrs=df['decade'].value_counts()
print(yrs)
plt.bar(yrs.index,yrs,width=4)
plt.xlabel('Decade')
plt.ylabel('Number of Songs')
plt.show()
# Out:
# decade
# 2010.0    185435
# 2000.0     93528
# 2020.0     53577
# 1990.0     42454
# 1980.0     19404
# 1970.0     16099
# 1960.0      9480
# 1950.0      1748
# 1940.0       148
# 1930.0        83
# 1920.0        49
# 1890.0        28
# 1900.0         5
# 1910.0         2
# Name: count, dtype: int64

# %% [markdown]
# Might be a good idea to cut out everything before 1950.

# %% [markdown]
# ### Number of songs per genre ###

# %%
grs=df['main_genre'].value_counts()
print(grs)
plt.barh(grs.index,grs)
plt.xlabel('Number of Songs')
plt.ylabel('Main Genre')
# Out:
# main_genre
# pop            85166
# rock           67202
# country        53297
# alternative    47239
# pop rock       39545
# punk           16065
# metal          11312
# rap            11159
# soul            7345
# jazz            6994
# reggae          3838
# electronic      2814
# Name: count, dtype: int64
# Text(0, 0.5, 'Main Genre')

# %% [markdown]
# ### Number of songs per number of sections: ###

# %%
secs=df['num_sections'].value_counts()
print(secs)
# Out:
# num_sections
# 1      187443
# 7       56574
# 6       50516
# 8       46168
# 5       33734
#         ...
# 42          1
# 203         1
# 140         1
# 47          1
# 36          1
# Name: count, Length: 125, dtype: int64

# %% [markdown]
# There are some crazy outliers, some songs have 100+ sections. Plot only those $\leq$ 20 sections, which end up comprising more than 99% of the data.

# %%
#bar plot
secs=df[df['num_sections']<=20].num_sections.value_counts()
print(secs)
print(secs.sum()) #accounts for over 99.9% of data
plt.bar(secs.index,secs)
plt.ylabel('Number of Songs')
plt.xlabel('Number of Sections')
# Out:
# num_sections
# 1     187443
# 7      56574
# 6      50516
# 8      46168
# 5      33734
# 9      28772
# 4      22404
# 10     15667
# 3      11146
# 2       8971
# 11      7966
# 12      4058
# 13      2069
# 14      1087
# 15       575
# 16       424
# 17       208
# 18       147
# 20        75
# 19        74
# Name: count, dtype: int64
# 478078
# Text(0.5, 0, 'Number of Sections')

# %%
#box and whisker grouped by genre
plt.figure()
df[df['num_sections']<=20].boxplot(column='num_sections',by='main_genre',figsize=(10,6))
plt.xlabel('Genre')
plt.suptitle('')
plt.title('Statistics for number of sections by genre')
plt.show()

# %%
#mean number of sections per genre
df[['num_sections','main_genre']].groupby('main_genre').mean()
# Out:
#              num_sections
# main_genre
# alternative      4.726116
# country          4.687450
# electronic       4.807747
# jazz             4.791822
# metal            5.429544
# pop              4.766914
# pop rock         4.425768
# punk             4.139122
# rap              4.446635
# reggae           4.186295
# rock             4.402384
# soul             4.901838

# %% [markdown]
# IQRs are basically the same in every genre. Punk and reggae have lower median number of sections per song while metal is high. The same trends are true for means.

# %%
#box and whisker grouped by decade
plt.figure()
df[df['num_sections']<=20].boxplot(column='num_sections',by='decade',figsize=(10,6))
plt.xlabel('Decade')
plt.suptitle('')
plt.title('Statistics for number of sections by decade')
plt.show()

# %%
#mean number of sections per decade
df[['num_sections','decade']].groupby('decade').mean()
# Out:
#         num_sections
# decade
# 1890.0      6.357143
# 1900.0      4.400000
# 1910.0      3.500000
# 1920.0      4.734694
# 1930.0      4.578313
# 1940.0      4.047297
# 1950.0      3.695080
# 1960.0      3.906224
# 1970.0      4.649357
# 1980.0      4.865852
# 1990.0      4.006030
# 2000.0      3.484422
# 2010.0      5.119088
# 2020.0      5.715606

# %% [markdown]
# Songs from the 90's and 2000's have a low meadian number of sections, while the 2000's also have a very low mean. The 2010's and 2020's both have high medians and high means.

# %% [markdown]
# ### Songs per total unique chords: ###

# %%
uchords=df.tot_unique_chords.value_counts()
print(uchords)
# Out:
# tot_unique_chords
# 4      92728
# 5      87065
# 6      71212
# 7      50166
# 3      42040
#        ...
# 114        1
# 86         1
# 104        1
# 93         1
# 90         1
# Name: count, Length: 102, dtype: int64

# %% [markdown]
# Again, some huge outliers. Limit plot to songs with $\leq$ 30 unique chords, which account for over 99.5% of all data.

# %%
uchords=df[df['tot_unique_chords']<=30].tot_unique_chords.value_counts()
print(uchords)
print(uchords.sum()) #accounts for over 99.5% of data
plt.bar(uchords.index,uchords)
plt.ylabel('Number of Songs')
plt.xlabel('Number of Unique Chords')
# Out:
# tot_unique_chords
# 4     92728
# 5     87065
# 6     71212
# 7     50166
# 3     42040
# 8     34191
# 9     23599
# 10    17016
# 11    12223
# 12     9056
# 13     6686
# 2      6251
# 14     5152
# 15     3874
# 16     3002
# 17     2459
# 18     1936
# 19     1566
# 20     1267
# 21     1057
# 22      838
# 23      721
# 24      596
# 25      509
# 26      416
# 27      340
# 28      337
# 29      248
# 30      226
# Name: count, dtype: int64
# 476777
# Text(0.5, 0, 'Number of Unique Chords')

# %%
#box and whisker grouped by genre
plt.figure()
df[df['tot_unique_chords']<=30].boxplot(column='tot_unique_chords',by='main_genre',figsize=(10,6))
plt.xlabel('Genre')
plt.suptitle('')
plt.title('Statistics for number of unique chords by genre')
plt.show()

# %%
#mean number of unique chords per genre
df[['tot_unique_chords','main_genre']].groupby('main_genre').mean()
# Out:
#              tot_unique_chords
# main_genre
# alternative           6.226190
# country               5.734657
# electronic            5.646766
# jazz                  8.518587
# metal                 7.689798
# pop                   6.849506
# pop rock              7.294399
# punk                  5.911796
# rap                   5.336679
# reggae                5.080511
# rock                  7.232315
# soul                  7.668754

# %% [markdown]
# Rap, reggae and electronic all have low medians/3rd quartiles and means. Metal, soul and jazz have the highest medians/3rd quartiels and means.

# %%
#box and whisker grouped by decade
plt.figure()
df[df['tot_unique_chords']<=30].boxplot(column='tot_unique_chords',by='decade',figsize=(10,6))
plt.xlabel('Decade')
plt.suptitle('')
plt.title('Statistics for number of unique chords by decade')
plt.show()

# %%
#mean number of unique chords per decade
df[['tot_unique_chords','decade']].groupby('decade').mean()
# Out:
#         tot_unique_chords
# decade
# 1890.0           5.785714
# 1900.0           5.800000
# 1910.0           6.500000
# 1920.0           9.285714
# 1930.0           8.783133
# 1940.0           8.209459
# 1950.0           7.759153
# 1960.0           7.619515
# 1970.0           8.184856
# 1980.0           7.668883
# 1990.0           7.123969
# 2000.0           6.674803
# 2010.0           6.348748
# 2020.0           6.463930

# %% [markdown]
# The means and interquartile distributions for post-2000's music seem to be lower than the rest.

# %% [markdown]
# ### Songs by total number of chords: ###

# %%
tchords=df.tot_chords.value_counts()
print(tchords)
# Out:
# tot_chords
# 72      5942
# 64      5932
# 60      5901
# 56      5689
# 61      5591
#         ...
# 601        1
# 1613       1
# 1603       1
# 542        1
# 431        1
# Name: count, Length: 931, dtype: int64

# %% [markdown]
# Once again, large outliers. Restrict plot to songs using $\leq$ 250 chords, which comprise more than 99.5% of total data. Since this feature is more continuous than the others, use histrogram instead of bar plot.

# %%
tchords=df[df['tot_chords']<=250].tot_chords.value_counts()
print(tchords)
print(tchords.sum()) #accounts for more than 99.5% data
#plt.bar(tchords.index,uchords)
plt.hist(df[df['tot_chords']<=250]['tot_chords'],bins=25)
plt.xlabel('Total number of chords')
plt.ylabel('Total number of songs')
plt.show()
# Out:
# tot_chords
# 72     5942
# 64     5932
# 60     5901
# 56     5689
# 61     5591
#        ...
# 250      25
# 249      23
# 245      21
# 243      20
# 244      19
# Name: count, Length: 248, dtype: int64
# 476668

# %%
#box and whisker grouped by genre
plt.figure()
df[df['tot_chords']<=250].boxplot(column='tot_chords',by='main_genre',figsize=(10,6))
plt.xlabel('Genre')
plt.suptitle('')
plt.title('Statistics for number of chords by genre')
plt.show()

# %%
#mean number of chords per genre
df[['tot_chords','main_genre']].groupby('main_genre').mean()
# Out:
#              tot_chords
# main_genre
# alternative   75.045175
# country       71.272192
# electronic    78.752310
# jazz          73.088504
# metal         91.503094
# pop           79.398762
# pop rock      81.269212
# punk          78.322378
# rap           76.555157
# reggae        73.107087
# rock          78.373441
# soul          77.321171

# %% [markdown]
# Metal again jumps out as having the highest statistics.

# %%
#box and whisker grouped by decade
plt.figure()
df[df['tot_chords']<=250].boxplot(column='tot_chords',by='decade',figsize=(10,6))
plt.xlabel('Decade')
plt.suptitle('')
plt.title('Statistics for number of chords by decade')
plt.show()

# %%
#mean number of chords per decade
df[['tot_chords','decade']].groupby('decade').mean()
# Out:
#         tot_chords
# decade
# 1890.0   88.500000
# 1900.0   64.800000
# 1910.0   60.000000
# 1920.0   68.204082
# 1930.0   66.578313
# 1940.0   59.209459
# 1950.0   56.840961
# 1960.0   63.802954
# 1970.0   76.980620
# 1980.0   80.904040
# 1990.0   73.260352
# 2000.0   70.257025
# 2010.0   78.608310
# 2020.0   79.815593

# %% [markdown]
# The interquartile distributions and means of total number of chords seem to be steadily rising since the 1950's.

# %% [markdown]
# ### Songs per unique chord density: ####

# %%
plt.hist(df.unique_chord_density,bins=20)
print(df.unique_chord_density.describe())
plt.xlabel('Unique Chord Density')
plt.ylabel('Total number of songs')
plt.show()
# Out:
# count    478551.000000
# mean          0.112432
# std           0.088742
# min           0.005435
# 25%           0.059524
# 50%           0.086957
# 75%           0.133333
# max           1.000000
# Name: unique_chord_density, dtype: float64

# %%
#box and whisker grouped by genre
plt.figure()
df.boxplot(column='unique_chord_density',by='main_genre',figsize=(10,6))
plt.xlabel('Genre')
plt.suptitle('')
plt.title('Statistics for unique chord density by genre')
plt.show()

# %%
#mean number of chords per decade
df[['unique_chord_density','main_genre']].groupby('main_genre').mean()
# Out:
#              unique_chord_density
# main_genre
# alternative              0.105020
# country                  0.102924
# electronic               0.097081
# jazz                     0.142143
# metal                    0.106069
# pop                      0.107379
# pop rock                 0.115611
# punk                     0.107645
# rap                      0.100369
# reggae                   0.107958
# rock                     0.123229
# soul                     0.118485

# %% [markdown]
# Jazz is far ahead of the others in terms of mean and interquartile distribution

# %%
#box and whisker grouped by decade
plt.figure()
df.boxplot(column='unique_chord_density',by='decade',figsize=(10,6))
plt.xlabel('Decade')
plt.suptitle('')
plt.title('Statistics for unique chord density by decade')
plt.show()

# %%
#mean number of chords per decade
df[['unique_chord_density','decade']].groupby('decade').mean()
# Out:
#         unique_chord_density
# decade
# 1890.0              0.094438
# 1900.0              0.141961
# 1910.0              0.143697
# 1920.0              0.149964
# 1930.0              0.165446
# 1940.0              0.159346
# 1950.0              0.150921
# 1960.0              0.146513
# 1970.0              0.131247
# 1980.0              0.121223
# 1990.0              0.130040
# 2000.0              0.125245
# 2010.0              0.098239
# 2020.0              0.096421

# %% [markdown]
# The mean and interquartile distributions seem to generally be shifting lower over time since the 1940's.
